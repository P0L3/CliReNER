# %% [markdown]
# Notebook for quality control of GLiNER results.

# %% [markdown]
# ## Journal List

# %% [markdown]
# 1. [Climate Dynamics](https://link.springer.com/journal/382)
#
# 2. [Ecological Applications](https://esajournals.onlinelibrary.wiley.com/journal/19395582)
#
# 3. [Ecosystem Health and Sustainability](https://spj.science.org/journal/ehs)
#
# 4. [Energy Policy](https://www.sciencedirect.com/journal/energy-policy)
#
# 5. [Global Change Biology](https://onlinelibrary.wiley.com/journal/13652486)
#
# 6. [International Journal of Climatology](https://rmets.onlinelibrary.wiley.com/journal/10970088)
#
# 7. [Journal of Climate](https://www.ametsoc.org/index.cfm/ams/publications/journals/journal-of-climate/)
#
# 8. [Journal of Geophysical Research: Atmospheres](https://agupubs.onlinelibrary.wiley.com/journal/21698996?journalRedirectCheck=true)
#
# 9.  [MDPI Air](https://www.mdpi.com/journal/air)
# 10. [MDPI Atmosphere](https://www.mdpi.com/journal/atmosphere)
# 11. [MDPI Climate](https://www.mdpi.com/journal/climate)
# 12. [MDPI Earth](https://www.mdpi.com/journal/earth)
# 13. [MDPI Ecologies](https://www.mdpi.com/journal/ecologies)
# 14. [MDPI Energies](https://www.mdpi.com/journal/energies)
# 15. [MDPI Environments](https://www.mdpi.com/journal/environments)
# 16. [MDPI Forests](https://www.mdpi.com/journal/forests)
# 17. [MDPI Fuels](https://www.mdpi.com/journal/fuels)
# 18. [MDPI Hydrology](https://www.mdpi.com/journal/hydrology)
# 19. [MDPI Meteorology](https://www.mdpi.com/journal/meteorology)
# 20. [MDPI Oceans](https://www.mdpi.com/journal/oceans)
# 21. [MDPI Recycling](https://www.mdpi.com/journal/recycling)
# 22. [MDPI Sustainable Chemistry](https://www.mdpi.com/journal/suschem)
# 23. [MDPI Water](https://www.mdpi.com/journal/water)
#
# 24. [Nature Climate Change](https://www.nature.com/nclimate/)
#
# 25. [Nature Geoscience](https://www.nature.com/ngeo/)
#
# 26. [NPJ Climate Action](https://www.nature.com/npjclimataction/)
#
# 27. [NPJ Climate and Atmospheric Science](https://www.nature.com/npjclimatsci/)
# 28. [NPJ Ocean Sustainability](https://www.nature.com/npjoceansustain/)
#
# 29. [PNAS](https://www.pnas.org/)

# %% [markdown]
# ## Data and Libraries

# %%
import pandas as pd
from os import listdir

from random import seed

# %% [markdown]
# Load original data to map to:

# %%
df = pd.read_pickle("DATA/ED4RE_2603.pickle")

# %% [markdown]
# Load names of GLiNER annotated papers:

# %%
processed_papers = listdir("RESULTS/GLINER_TESTS_FULL")

IDs = [a.split("_")[1] for a in processed_papers if ".json" in a]

# Add original index
df["backtrace_index"] = range(len(df))

# %% [markdown]
# Check if IDs match `.iloc[]` of the paper in original pandas dataframe:

# %%
print(IDs[2])
print([a for a in processed_papers if IDs[2] in a])

print(df.iloc[int(IDs[2])][["Content", "Title"]])
# Out:
# 22235
# ['5_22235_An_Overview_of_Water_Markets_in_Southern_Africa__An_Option_for_Water_Management_in_Times_of_Scarcity.json']
# Content    Southern Africa faces acute water scarcity cha...
# Title      A n   O v e r v i e w   o f   W a t e r   M a ...
# Name: 712, dtype: object

# %% [markdown]
# > **Observation 1**: Original Pandas Dataframe `ED4RE_2603` and paper IDs in `GLINER_TESTS_FULL` match. -> Can filter the annotated data back based on meta-columns such as journal.

# %% [markdown]
# ## Sampling

# %% [markdown]
# Filter the orignal dataset by annotated papers:

# %%
# filtered_df = df.loc[df.index[[int(ID) for ID in IDs]]]
filtered_df = df.iloc[[int(ID) for ID in IDs]]
print(len(filtered_df))
# Out:
# 27215

# %%
def list_to_string(row):
    """
    Converts a list of strings into a single space-separated string.
    
    Parameters:
    row (list or str): The input data to be converted.
    
    Returns:
    str: A space-separated string if input is a list, the original string if input is a string,
         or "no_journal" if input is of an unsupported type.
    """
    if isinstance(row, list):
        row = " ".join(row)
        
        
    if isinstance(row, str):
        if "pnas" in row:
            return "PNAS"
        elif "joc" in row:
            return "IJOC"
        elif "eap" in row or "10.1890" in row or "10.2307" in row:
            return "ECOAPP"
        else:
            return row
    else:
        return "no_journal"

# %%
filtered_df["Journal"] = filtered_df.Journal.apply(list_to_string)
# Out:
# /tmp/ipykernel_8202/1684264378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Journal"] = filtered_df.Journal.apply(list_to_string)

# %%
JOURNAL_LIST = filtered_df.Journal.unique()
JOURNAL_LIST.sort()
print(JOURNAL_LIST)
# Out:
# ['/10.1002/15-0976' 'Advances in Atmospheric Sciences'
#  'Agriculture, Ecosystems &amp; Environment' 'Air' 'Annals of Botany'
#  'Annals of the Entomological Society of America'
#  'Annals of the New York Academy of Sciences'
#  'Annual Review of Plant Biology'
#  'Applied Physics B Photophysics and Laser Chemistry' 'Atmosphere'
#  'Atmospheric Chemistry and Physics' 'Atmospheric Measurement Techniques'
#  'Australian &amp; New Zealand Journal of Statistics'
#  'BMC Evolutionary Biology' 'BioScience' 'Biogeosciences'
#  'Biological Conservation' 'Biological Reviews'
#  'Bulletin of Environmental Contamination and Toxicology'
#  'Bulletin of the American Meteorological Society'
#  'Canadian Journal of Forest Research' 'Carbon Management' 'Chemosphere'
#  'Climate' 'Climate Dynamics' 'Climate of the Past' 'Climatic Change'
#  'Current Biology' 'ECOAPP' 'Earth' 'Earth System Science Data'
#  'Earth, Planets and Space' 'Ecological Applications'
#  'Ecological Monographs' 'Ecologies' 'Ecology' 'Ecology Letters'
#  'Ecosphere' 'Energies' 'Energy Policy' 'Environmental Microbiology'
#  'Environmental Science &amp; Technology' 'Environments'
#  'Eos, Transactions American Geophysical Union'
#  'Forest Ecology and Management' 'Forestry' 'Forests' 'Freshwater Science'
#  'Frontiers in Ecology and Evolution' 'Frontiers in Marine Science'
#  'Fuels' 'Functional Ecology' 'Geochimica et Cosmochimica Acta'
#  'Geophysical Research Letters' 'Geoscientific Model Development'
#  'Global Biogeochemical Cycles' 'Global Change Biology' 'Hydrology'
#  'IBM Journal of Research and Development'
#  'IEEE Transactions on Geoscience and Remote Sensing' 'IJOC'
#  'ISPRS Journal of Photogrammetry and Remote Sensing'
#  'Inhalation Toxicology'
#  'Integrated Environmental Assessment and Management'
#  'Integrative and Comparative Biology'
#  'International Journal of Climatology'
#  'International Journal of Greenhouse Gas Control'
#  'Journal of Applied Ecology'
#  'Journal of Applied Meteorology and Climatology'
#  'Journal of Atmospheric and Solar-Terrestrial Physics'
#  'Journal of Climate' 'Journal of Earth System Science'
#  'Journal of Experimental Botany' 'Journal of Fluid Mechanics'
#  'Journal of Geophysical Research'
#  'Journal of Geophysical Research: Atmospheres'
#  'Journal of Geophysical Research: Oceans'
#  'Journal of Geophysical Research: Space Physics'
#  'Journal of Hydrometeorology' 'Journal of Meteorological Research'
#  'Journal of Physics D: Applied Physics' 'Journal of Statistical Software'
#  'Journal of the Atmospheric Sciences' 'Limnology and Oceanography'
#  'Machine Learning' 'Marine Ecology Progress Series' 'Marine Policy'
#  'Meteorology' 'Meteorology and Atmospheric Physics'
#  'Monthly Weather Review' 'Nature' 'Nature Climate Change'
#  'Nature Ecology &amp; Evolution' 'Nature Geoscience' 'New Phytologist'
#  'Nonlinear Processes in Geophysics' 'Oceans' 'Oikos' 'PLOS ONE' 'PNAS'
#  'Paleoceanography'
#  'Philosophical Transactions of the Royal Society B: Biological Sciences'
#  'Physical Review Research' 'Plant and Soil'
#  'Plant, Cell &amp; Environment'
#  'Proceedings of the National Academy of Sciences'
#  'Proceedings of the Royal Society B: Biological Sciences'
#  'Quarterly Journal of the Royal Meteorological Society'
#  'Quaternary International' 'Recycling' 'Reviews of Geophysics'
#  'Russian Meteorology and Hydrology' 'Science' 'Scientific Data'
#  'Scientific Reports' 'Soil Research' 'Soil and Tillage Research'
#  'Spectrochimica Acta Part B: Atomic Spectroscopy' 'Sustain.'
#  'Tellus B: Chemical and Physical Meteorology' 'The American Naturalist'
#  'The ISME Journal' 'The Journal of Parasitology' 'The Physics of Fluids'
#  'Water' 'Weather and Forecasting' 'no_info' 'no_journal']

# %% [markdown]
# Create a mapping to original scraped journals (commented parts represent journals with good samples):

# %%
J_L = [
    # "Climate Dynamics",
    # "Ecological Applications;ECOAPP",
    # EHS
    # "Energy Policy",
    # "Global Change Biology",
    # "International Journal of Climatology;IJOC",
    # "Journal of Climate",
    # "Journal of Geophysical Research;Journal of Geophysical Research: Atmospheres;Journal of Geophysical Research: Oceans;Journal of Geophysical Research: Space Physics",
    # "Air", "Atmosphere", "Climate", "Earth", "Ecologies", "Energies", "Environments", "Forests", "Fuels", "Hydrology", "Meteorology", "Oceans", "Recycling", "Sustain.", "Water", # MDPI
    # "Nature Climate Change",
    # "Nature Geoscience",
    # NPJ Climate Action
    # NPJ Climate and Atmospheric Science
    # NPJ Ocean Sustainability
    # "PNAS"
]

# %%
seed(2003)
sampled_rows = []  # List to store the sampled rows

for j in J_L:
    print(f"Processing journal: {j}")
    temp_sample = filtered_df[filtered_df["Journal"].isin(j.split(";"))].sample(60)  # Sample 1 row
    
    for _, row in temp_sample.iterrows():
        print("Title:", row["Title"])
        print("DOI: ", row["DOI"])
        print("Year: ", row["Date"])
        print("backtrace_index:", row["backtrace_index"])
        print()
    
    sampled_rows.append(temp_sample)  # Append the sampled row to the list
    
    print()  # For readability
    print()

# Concatenate all sampled rows into a single DataFrame
new_df = pd.concat(sampled_rows, ignore_index=True)

# If you want to check the final DataFrame
print(new_df)

# %%
new_df.to_pickle("gliner_analysis_test_sample_2.pickle")
# new_df.to_csv

# %%
processed_papers[0].split("_")
# Out:
# ['5',
#  '4993',
#  'Accuracy',
#  'and',
#  'Reliability',
#  'Analysis',
#  'of',
#  'Pipe',
#  'Irrigation',
#  'Metering',
#  'Device',
#  'for',
#  'Sandy',
#  'Water',
#  'Source.json']

# %%
paper_list = new_df.backtrace_index.to_list()
sample_list = [p for p in processed_papers if int(p.split("_")[1]) in paper_list]
# paper_list
# [p for p in processed_papers if p.split("_")[1] == "87857"]

# %%
print(sample_list)
print(len(sample_list))
# Out:
# ['5_10167_Clinical_Observations_Associated_with_Phenobarbital_Serum_Monitoring_to_Manage_Epilepsy_in_a_California_Sea_Lion_with_Domoic_Acid_Toxicosis.json', '5_63670_Restoring_function__Positive_responses_of_carbon_and_nitrogen_to_20_years_of_hydrologic_restoration_in_montane_meadows.json', '5_6641_Assessment_of_Non-Anthropogenic_Addition_of_Uric_Acid_to_a_Water_Treatment_Wetlands.json', '5_68117_Interannual_variation_in_methane_emissions_from_tropical_wetlands_triggered_by_repeated_El_Nino_Southern_Oscillation.json', '5_83977_Soil_emissions_of_nitrous_oxide_in_fire-prone_African_savannas.json', '5_170785_Recent_reduced_abyssal_overturning_and_ventilation_in_the_Australian_Antarctic_Basin.json', '5_62294_Mechanisms_of_Asian_Summer_Monsoon_Changes_in_Response_to_Anthropogenic_Forcing_in_CMIP5_Models_.json', '5_30003_Effects_of_Climate_and_Drought_on_Stem_Diameter_Growth_of_Urban_Tree_Species.json', '5_10061_Effect_of_Na_Doping_on_the_Electrochemical_Performance_of_Li1.2Ni0.13Co0.13Mn0.54O2_Cathode_for_Lithium-Ion_Batteries.json', '5_170991_Global_maps_of_twenty-first_century_forest_carbon_fluxes.json', '5_13798_Analytical_Study_for_the_Determination_of_the_Energy_Use_Potential_of_Forest_Dendromass_in_the_Czech_Republic.json', '5_65114_INCREASED_COMPETITIVE_ABILITY_OF_AN_INVASIVE_TREE_MAY_BE_LIMITED_BY_AN_INVASIVE_BEETLE.json', '5_39322_Evaluating_Possible_Changes_in_Air_Temperature_and_Precipitation_Patterns_in_Mozambique_by_Comparing_Present_and_Future_RegCM4_Simulation.json', '5_16811_Synthesis_and_Characterization_of_Epoxidized_Beechwood_Pyrolysis_Bio-Oil_as_a_Curing_Agent_of_Bio-Based_Novolac_Resin.json', '5_10662_Design_and_Implementation_of_a_Smart_Lithium-Ion_Battery_System_with_Real-Time_Fault_Diagnosis_Capability_for_Electric_Vehicles.json', '5_1051_Trends_in_upper_tropospheric_water_vapour_over_the_Tibetan_Plateau_from_remote_sensing.json', '5_41282_Circulation_of_137Cs_in_Various_Forest_Plants_in_the_Chornobyl_Exclusion_Zone_during_the_Year.json', '5_13006_Assessment_of_Physicochemical_Properties_and_Comparative_Pollution_Status_of_the_Dhaleshwari_River_in_Bangladesh.json', '5_40290_Comparison_between_Snow_Albedo_Obtained_from_Landsat_TM,_ETM+_Imagery_and_the_SPOT_VEGETATION_Albedo_Product_in_a_Mediterranean_Mountainous_Site.json', '5_33310_Coastal_Quarries_as_Relative_Sea-Level_Markers__A_Methodological_Approach_Applied_in_the_Apulia_Region_(Southern_Italy).json', '5_35800_Estimating_the_Statistical_Significance_of_Cross–Correlations_between_Hydroclimatic_Processes_in_the_Presence_of_Long–Range_Dependence.json', '5_32771_Decomposition_of_Used_Tyre_Rubber_by_Pyrolysis__Enhancement_of_the_Physical_Properties_of_the_Liquid_Fraction_Using_a_Hydrogen_Stream.json', '5_46034_Genus-Physiognomy-Ecosystem_(GPE)_System_for_Satellite-Based_Classification_of_Plant_Communities.json', '5_171181_Drivers_to_increase_eco-efficiencies_in_Uruguay,_Peru,_and_Panama.json', '5_12778_A_Correlation–Scale–Threshold_Method_for_Spatial_Variability_of_Rainfall.json', '5_45266_Spatial_Distribution_of_Snow_Cover_in_Tibet_and_Topographic_Dependence.json', '5_82002_An_estimate_of_the_impact_of_stratosphere-to-troposphere_transport_(STT)_on_the_lower_free_tropospheric_ozone_over_the_Alps_usingBe_andBe_measurements.json', '5_27835_Assessing_Climate_Driven_Malaria_Variability_in_Ghana_Using_a_Regional_Scale_Dynamical_Model.json', '5_22971_Optimization_of_Solid-State_Fermentation_of_Switchgrass_Using_White-Rot_Fungi_for_Biofuel_Production.json', '5_69344_Deﬁning_functional_biomes_and_monitoring_their_change_globally.json', '5_63311_Evaluation_of_MERRA_Land_Surface_Estimates_in_Preparation_for_the_Soil_Moisture_Active_Passive_Mission.json', '5_55512_Comparison_of_Satellite_Rainfall_Estimates_and_Rain_Gauge_Measurements_in_Italy,_and_Impact_on_Landslide_Modeling.json', '5_10756_Air_Pollution_Tolerance_Index_and_Heavy_Metals_Accumulation_of_Tree_Species_for_Sustainable_Environmental_Management_in_Megacity_of_Lahore.json', '5_50441_Food_Waste_Digestate-Bas ...
# 50

# %% [markdown]
# ### Copy

# %% [markdown]
# Copies sampled papers to a new folder:

# %%
import shutil
import os

# List of filenames
file_list = sample_list

# Define the source directory where the files currently are
source_dir = '/home/p0l3/RAD/CWED4ETA/CWED4ETA/CWED4ETA/RESULTS/GLINER_TESTS_FULL'

# Define the destination directory where you want to copy the files
destination_dir = '/home/p0l3/RAD/CWED4ETA/CWED4ETA/CWED4ETA/RESULTS/GLINER_TESTS_SAMPLE'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Loop through the list and copy each file
for file_name in file_list:
    # Create the full path to the source file
    source_file = os.path.join(source_dir, file_name)
    
    # Create the full path to the destination file
    destination_file = os.path.join(destination_dir, file_name)
    
    # Copy the file
    shutil.copy(source_file, destination_file)
    print(f"Copied {file_name} to {destination_dir}")

# %% [markdown]
# ## Load Final Smaple

# %% [markdown]
# Sampling process needed fixing, for better quality articles as representatives per journal (2 articles per journal -> 50 articles).
