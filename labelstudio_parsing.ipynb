# %% [markdown]
# Python notebook to format labelstudio json into different input formats.

# %% [markdown]
# For loading, alteration of function from [GLINER/dataset_processing](CWED4ETA/GLINER/dataset_processing.py) is used. Important problem is taking the most correct annotations. For now, one that is most correct can be chosen based on the annotator denoted by "completed_by" value having an id number, for now:
#
# 1 - Original relation + named entity annotation
#
# 2 - Named entity annotation
#
# 3 - Named entity annotation (outsider tests)
#
# Thus, ordering of importance should be 2, 1, 3. With Annotator 2 being the most reliable. This resoning should be changed later on.

# %% [markdown]
# ## HuggingFace Dataset

# %%
from dataset_processing import cwed4eta_process_json_file, transform_to_ner_format, CLIRENER_LABELS_V1, ner_dataset_to_hf_format


CWED4ETA_DIR = "DATA/LABEL_STUDIO/project-28-at-2025-11-11-12-33-f873727e.json" # PC2 

data = cwed4eta_process_json_file(CWED4ETA_DIR)

transformed_dataset, tag_map = transform_to_ner_format(data, CLIRENER_LABELS_V1)

hf_dataset = ner_dataset_to_hf_format(transformed_dataset, tag_map)

print(hf_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 805
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 114
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 120
#     })
# })

# %%
print(hf_dataset)
print()
print(hf_dataset["test"])
print()
print(hf_dataset["test"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 805
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 114
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 120
#     })
# })
#
# Dataset({
#     features: ['id', 'tokens', 'ner_tags'],
#     num_rows: 120
# })
#
# {'id': '2', 'tokens': ['This', 'report', 'details', 'serum', 'monitoring', 'over', '33', 'months', 'in', 'an', '8-year-old', 'male', 'sea', 'lion', '.'], 'ner_tags': [0, 39, 0, 29, 30, 0, 55, 56, 0, 0, 49, 0, 35, 36, 0]}

# %% [markdown]
# Upload to HF:

# %%
hf_dataset.push_to_hub("P0L3/CliReNER_v_1_0_28")
# Out:
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 333.38ba/s]
# Uploading files as a binary IO buffer is not supported by Xet Storage. Falling back to HTTP upload.
# Uploading the dataset shards: 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 1000.31ba/s]
# Uploading files as a binary IO buffer is not supported by Xet Storage. Falling back to HTTP upload.
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 999.83ba/s]
# Uploading files as a binary IO buffer is not supported by Xet Storage. Falling back to HTTP upload.
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/P0L3/CliReNER_v_1_0_28/commit/7597c9ff1bd27452a7d23bc3f288014fe88e781f', commit_message='Upload dataset', commit_description='', oid='7597c9ff1bd27452a7d23bc3f288014fe88e781f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/P0L3/CliReNER_v_1_0_28', endpoint='https://huggingface.co', repo_type='dataset', repo_id='P0L3/CliReNER_v_1_0_28'), pr_revision=None, pr_num=None)
