# %% [markdown]
# Python notebook to format labelstudio json into different input formats.

# %% [markdown]
# For loading, alteration of function from [GLINER/dataset_processing](CWED4ETA/GLINER/dataset_processing.py) is used. Important problem is taking the most correct annotations. For now, one that is most correct can be chosen based on the annotator denoted by "completed_by" value having an id number, for now:
#
# 1 - Original relation + named entity annotation
#
# 2 - Named entity annotation
#
# 3 - Named entity annotation (outsider tests)
#
# Thus, ordering of importance should be 2, 1, 3. With Annotator 2 being the most reliable. This resoning should be changed later on.

# %% [markdown]
# ## HuggingFace Dataset

# %%
from GLINER.dataset_processing import cwed4eta_process_json_file, transform_to_ner_format, CWED4ETA_LABELS, ner_dataset_to_hf_format


CWED4ETA_DIR = "DATA/LABEL_STUDIO/project-6-at-2025-10-21-07-38-62e6d4cc.json" # PC2 

data = cwed4eta_process_json_file(CWED4ETA_DIR)

transformed_dataset, tag_map = transform_to_ner_format(data, CWED4ETA_LABELS)

hf_dataset = ner_dataset_to_hf_format(transformed_dataset, tag_map)

print(hf_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 714
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 112
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 100
#     })
# })

# %%
print(hf_dataset)
print()
print(hf_dataset["test"])
print()
print(hf_dataset["test"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 714
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 112
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 100
#     })
# })
#
# Dataset({
#     features: ['id', 'tokens', 'ner_tags'],
#     num_rows: 100
# })
#
# {'id': '1', 'tokens': ['Phenobarbital', 'has', 'been', 'used', 'for', 'several', 'decades', 'to', 'manage', 'seizures', ',', 'although', 'reports', 'are', 'limited', 'correlating', 'dosing', ',', 'serum', 'monitoring', 'and', 'clinical', 'efficacy', 'in', 'this', 'species', '.'], 'ner_tags': [9, 0, 0, 0, 0, 53, 54, 0, 0, 11, 0, 0, 39, 0, 45, 0, 29, 0, 29, 30, 0, 29, 30, 0, 0, 35, 0]}

# %% [markdown]
# Upload to HF:

# %%
hf_dataset.push_to_hub("P0L3/CliReNER_v_0_0_26")
# Out:
# ...
# Deleting unused files from dataset repository:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
